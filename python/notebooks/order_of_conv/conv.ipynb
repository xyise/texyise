# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
e = [0.5]
n = list(range(1, 11))
for i in n:
    if i == 10:
        continue
    e.append(e[i-1]**2)
e
# Out:
# [0.5,
#  0.25,
#  0.0625,
#  0.00390625,
#  1.52587890625e-05,
#  2.3283064365386963e-10,
#  5.421010862427522e-20,
#  2.938735877055719e-39,
#  8.636168555094445e-78,
#  7.458340731200207e-155]

# %%
plt.figure()
plt.plot(np.exp(n), np.log(e), '.--')
plt.show()
